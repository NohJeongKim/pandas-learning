# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_copy=df.copy()
df_copy.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_copy["VIP"]=True # VIP 열을 추가시켜주었다.
df_copy.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone   VIP
# 0    man        True  NaN  Southampton    no  False  True
# 1  woman       False    C    Cherbourg   yes  False  True
# 2  woman       False  NaN  Southampton   yes   True  True
# 3  woman       False    C  Southampton   yes  False  True
# 4    man        True  NaN  Southampton    no   True  True

# %%
df_copy.insert(1, "VIP2", True)
df_copy.head()
# Out:
#    survived  VIP2  pclass     sex   age  sibsp  parch     fare embarked  \
# 0         0  True       3    male  22.0      1      0   7.2500        S
# 1         1  True       1  female  38.0      1      0  71.2833        C
# 2         1  True       3  female  26.0      0      0   7.9250        S
# 3         1  True       1  female  35.0      1      0  53.1000        S
# 4         0  True       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone   VIP
# 0  Third    man        True  NaN  Southampton    no  False  True
# 1  First  woman       False    C    Cherbourg   yes  False  True
# 2  Third  woman       False  NaN  Southampton   yes   True  True
# 3  First  woman       False    C  Southampton   yes  False  True
# 4  Third    man        True  NaN  Southampton    no   True  True

# %%
df_copy.drop(1)
# Out:
#      survived  VIP2  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0  True       3    male  22.0      1      0   7.2500        S
# 2           1  True       3  female  26.0      0      0   7.9250        S
# 3           1  True       1  female  35.0      1      0  53.1000        S
# 4           0  True       3    male  35.0      0      0   8.0500        S
# 5           0  True       3    male   NaN      0      0   8.4583        Q
# ..        ...   ...     ...     ...   ...    ...    ...      ...      ...
# 886         0  True       2    male  27.0      0      0  13.0000        S
# 887         1  True       1  female  19.0      0      0  30.0000        S
# 888         0  True       3  female   NaN      1      2  23.4500        S
# 889         1  True       1    male  26.0      0      0  30.0000        C
# 890         0  True       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone   VIP
# ...

# %%
df_copy.drop(np.arange(2, 10))
# Out:
#      survived  VIP2  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0  True       3    male  22.0      1      0   7.2500        S
# 1           1  True       1  female  38.0      1      0  71.2833        C
# 10          1  True       3  female   4.0      1      1  16.7000        S
# 11          1  True       1  female  58.0      0      0  26.5500        S
# 12          0  True       3    male  20.0      0      0   8.0500        S
# ..        ...   ...     ...     ...   ...    ...    ...      ...      ...
# 886         0  True       2    male  27.0      0      0  13.0000        S
# 887         1  True       1  female  19.0      0      0  30.0000        S
# 888         0  True       3  female   NaN      1      2  23.4500        S
# 889         1  True       1    male  26.0      0      0  30.0000        C
# 890         0  True       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone   VIP
# ...

# %%
df_copy.drop([1,3,5,7,9])
# Out:
#      survived  VIP2  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0  True       3    male  22.0      1      0   7.2500        S
# 2           1  True       3  female  26.0      0      0   7.9250        S
# 4           0  True       3    male  35.0      0      0   8.0500        S
# 6           0  True       1    male  54.0      0      0  51.8625        S
# 8           1  True       3  female  27.0      0      2  11.1333        S
# ..        ...   ...     ...     ...   ...    ...    ...      ...      ...
# 886         0  True       2    male  27.0      0      0  13.0000        S
# 887         1  True       1  female  19.0      0      0  30.0000        S
# 888         0  True       3  female   NaN      1      2  23.4500        S
# 889         1  True       1    male  26.0      0      0  30.0000        C
# 890         0  True       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone   VIP
# ...

# %%
df_copy.head()
# Out:
#    survived  VIP2  pclass     sex   age  sibsp  parch     fare embarked  \
# 0         0  True       3    male  22.0      1      0   7.2500        S
# 1         1  True       1  female  38.0      1      0  71.2833        C
# 2         1  True       3  female  26.0      0      0   7.9250        S
# 3         1  True       1  female  35.0      1      0  53.1000        S
# 4         0  True       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone   VIP
# 0  Third    man        True  NaN  Southampton    no  False  True
# 1  First  woman       False    C    Cherbourg   yes  False  True
# 2  Third  woman       False  NaN  Southampton   yes   True  True
# 3  First  woman       False    C  Southampton   yes  False  True
# 4  Third    man        True  NaN  Southampton    no   True  True

# %%
df_copy.drop("class", axis=1).head()
# Out:
#    survived  VIP2  pclass     sex   age  sibsp  parch     fare embarked  \
# 0         0  True       3    male  22.0      1      0   7.2500        S
# 1         1  True       1  female  38.0      1      0  71.2833        C
# 2         1  True       3  female  26.0      0      0   7.9250        S
# 3         1  True       1  female  35.0      1      0  53.1000        S
# 4         0  True       3    male  35.0      0      0   8.0500        S
#
#      who  adult_male deck  embark_town alive  alone   VIP
# 0    man        True  NaN  Southampton    no  False  True
# 1  woman       False    C    Cherbourg   yes  False  True
# 2  woman       False  NaN  Southampton   yes   True  True
# 3  woman       False    C  Southampton   yes  False  True
# 4    man        True  NaN  Southampton    no   True  True

# %%
df_copy.drop(["survived", "VIP2", "VIP"], axis=1, inplace=True)
df_copy.head()
# Out:
#    pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    male  22.0      1      0   7.2500        S  Third    man
# 1       1  female  38.0      1      0  71.2833        C  First  woman
# 2       3  female  26.0      0      0   7.9250        S  Third  woman
# 3       1  female  35.0      1      0  53.1000        S  First  woman
# 4       3    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# # 연습문제

# %%
df_copy=df.copy()
df_copy.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_copy.drop([1,3,5], axis=0, inplace=True)

# %%
df_copy.drop(["embarked", "class", "alone"], axis=1, inplace=True)

# %%
df_copy.head(10)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare    who  adult_male  \
# 0          0       3    male  22.0      1      0   7.2500    man        True
# 2          1       3  female  26.0      0      0   7.9250  woman       False
# 4          0       3    male  35.0      0      0   8.0500    man        True
# 6          0       1    male  54.0      0      0  51.8625    man        True
# 7          0       3    male   2.0      3      1  21.0750  child       False
# 8          1       3  female  27.0      0      2  11.1333  woman       False
# 9          1       2  female  14.0      1      0  30.0708  child       False
# 10         1       3  female   4.0      1      1  16.7000  child       False
# 11         1       1  female  58.0      0      0  26.5500  woman       False
# 12         0       3    male  20.0      0      0   8.0500    man        True
#
#    deck  embark_town alive
# 0   NaN  Southampton    no
# 2   NaN  Southampton   yes
# 4   NaN  Southampton    no
# ...
