# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data/seoul_population.csv") # 한글이 깨지면 utf-8 이용하기.
df.head()
# Out:
#      연도  자치구        세대수      인구 합계   남자 인구 합계   여자 인구 합계  한국인 인구 합계  \
# 0  2020   합계  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465
# 1  2020  종로구     75,003    158,996     76,876     82,120    149,384
# 2  2020   중구     63,686    134,635     65,776     68,859    125,240
# 3  2020  용산구    113,093    244,645    118,835    125,810    230,040
# 4  2020  성동구    135,870    300,505    146,424    154,081    293,556
#
#   한국인 남자 인구수 한국인 여자 인구수 등록 외국인 인구 합계 등록 외국인 인구 남자수 등록 외국인 인구 여자수  세대당 인구  \
# 0  4,701,723  4,966,742      242,623       114,799       127,824    2.19
# 1     72,635     76,749        9,612         4,241         5,371    1.99
# 2     61,222     64,018        9,395         4,554         4,841    1.97
# 3    110,722    119,318       14,605         8,113         6,492    2.03
# 4    143,387    150,169        6,949         3,037         3,912    2.16
#
#   65세 이상 고령자 수
# 0    1,568,331
# 1       28,507
# 2       24,495
# 3       40,247
# 4       45,603

# %%
chunk=pd.read_csv("data/seoul_population.csv", chunksize=10)
chunk_list=list(chunk)
chunk_list
# Out:
# [     연도   자치구        세대수      인구 합계   남자 인구 합계   여자 인구 합계  한국인 인구 합계  \
#  0  2020    합계  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465
#  1  2020   종로구     75,003    158,996     76,876     82,120    149,384
#  2  2020    중구     63,686    134,635     65,776     68,859    125,240
#  3  2020   용산구    113,093    244,645    118,835    125,810    230,040
#  4  2020   성동구    135,870    300,505    146,424    154,081    293,556
#  5  2020   광진구    167,427    360,109    173,000    187,109    346,682
#  6  2020  동대문구    167,598    357,014    175,322    181,692    342,837
#  7  2020   중랑구    185,920    399,562    197,118    202,444    394,702
#  8  2020   성북구    195,396    447,056    214,658    232,398    437,153
#  9  2020   강북구    145,896    311,569    151,466    160,103    308,055
#
#    한국인 남자 인구수 한국인 여자 인구수 등록 외국인 인구 합계 등록 외국인 인구 남자수 등록 외국인 인구 여자수  세대당 인구  \
#  0  4,701,723  4,966,742      242,623       114,799       127,824    2.19
# ...

# %%
for df in chunk_list: # chunksize와 반복문을 이용해서 csv 파일을 잘라서 표기할 수 있다.
    display(df)
# Out:
#      연도   자치구        세대수      인구 합계   남자 인구 합계   여자 인구 합계  한국인 인구 합계  \
# 0  2020    합계  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465
# 1  2020   종로구     75,003    158,996     76,876     82,120    149,384
# 2  2020    중구     63,686    134,635     65,776     68,859    125,240
# 3  2020   용산구    113,093    244,645    118,835    125,810    230,040
# 4  2020   성동구    135,870    300,505    146,424    154,081    293,556
# 5  2020   광진구    167,427    360,109    173,000    187,109    346,682
# 6  2020  동대문구    167,598    357,014    175,322    181,692    342,837
# 7  2020   중랑구    185,920    399,562    197,118    202,444    394,702
# 8  2020   성북구    195,396    447,056    214,658    232,398    437,153
# 9  2020   강북구    145,896    311,569    151,466    160,103    308,055
#
#   한국인 남자 인구수 한국인 여자 인구수 등록 외국인 인구 합계 등록 외국인 인구 남자수 등록 외국인 인구 여자수  세대당 인구  \
# 0  4,701,723  4,966,742      242,623       114,799       127,824    2.19
# ...

# %%
df=pd.concat(chunk_list) # concat 이용해서 원래의 형태로 만들어줄 수 있다.
df
# Out:
#       연도   자치구        세대수      인구 합계   남자 인구 합계   여자 인구 합계  한국인 인구 합계  \
# 0   2020    합계  4,417,954  9,911,088  4,816,522  5,094,566  9,668,465
# 1   2020   종로구     75,003    158,996     76,876     82,120    149,384
# 2   2020    중구     63,686    134,635     65,776     68,859    125,240
# 3   2020   용산구    113,093    244,645    118,835    125,810    230,040
# 4   2020   성동구    135,870    300,505    146,424    154,081    293,556
# 5   2020   광진구    167,427    360,109    173,000    187,109    346,682
# 6   2020  동대문구    167,598    357,014    175,322    181,692    342,837
# 7   2020   중랑구    185,920    399,562    197,118    202,444    394,702
# 8   2020   성북구    195,396    447,056    214,658    232,398    437,153
# 9   2020   강북구    145,896    311,569    151,466    160,103    308,055
# 10  2020   도봉구    139,114    327,361    159,420    167,941    325,257
# 11  2020   노원구    218,270    527,032    254,188    272,844    523,037
# ...

# %%
excel=pd.read_excel("data/seoul_transportation.xlsx", engine="openpyxl", sheet_name="버스")
excel.head()
# Out:
#   대중교통구분      년월     승차총승객수
# 0     버스  201711  163443126
# 1     버스  201712  162521011
# 2     버스  201801  153335185
# 3     버스  201802  134768582
# 4     버스  201803  166177855

# %%
excel.to_csv("sample_bus_data.csv", index=False) # excel To csv

# %%
from IPython.display import Image # IPython에서 P가 대문자임을 기억하기.

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include=object) # 문자형도 알 수 있다.
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df["who"].value_counts() # who column의 데이터의 개수를 세어준다.
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %% [markdown]
# # 연습문제

# %%
df["embark_town"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df.ndim # DataFrame은 2차원이다.
# Out:
# 2

# %%
df.shape
# Out:
# (891, 15)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.values
# Out:
# array([[0, 3, 'male', ..., 'Southampton', 'no', False],
#        [1, 1, 'female', ..., 'Cherbourg', 'yes', False],
#        [1, 3, 'female', ..., 'Southampton', 'yes', True],
#        ...,
#        [0, 3, 'female', ..., 'Southampton', 'no', False],
#        [1, 1, 'male', ..., 'Cherbourg', 'yes', True],
#        [0, 3, 'male', ..., 'Queenstown', 'no', True]], dtype=object)

# %%
df.T
# Out:
#                      0          1            2            3            4    \
# survived               0          1            1            1            0
# pclass                 3          1            3            1            3
# sex                 male     female       female       female         male
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# parch                  0          0            0            0            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# adult_male          True      False        False        False         True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df["pclass"].astype("int32").head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: pclass, dtype: int32

# %%
df["pclass"].astype("float64").head()
# Out:
# 0    3.0
# 1    1.0
# 2    3.0
# 3    1.0
# 4    3.0
# Name: pclass, dtype: float64

# %%
df["pclass"].astype("str").head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: pclass, dtype: object

# %%
df["pclass"].astype("category").head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: pclass, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
df.sort_index(ascending=False).head() # 내림차순으로 정렬하기
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %%
df.sort_index().head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sort_values(by="age").head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False

# %%
df.sort_values(by="class", ascending=False).head() # 내림차순 정렬하기
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 0           0       3    male  22.0      1      0  7.2500        S  Third
# 511         0       3    male   NaN      0      0  8.0500        S  Third
# 500         0       3    male  17.0      0      0  8.6625        S  Third
# 501         0       3  female  21.0      0      0  7.7500        Q  Third
# 502         0       3  female   NaN      0      0  7.6292        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 511    man        True  NaN  Southampton    no   True
# 500    man        True  NaN  Southampton    no   True
# 501  woman       False  NaN   Queenstown    no   True
# 502  woman       False  NaN   Queenstown    no   True

# %%
df.sort_values(by=["age", "fare"]).head(10) # 2개 이상인 경우에는 앞의 요소에 뒤 요소가 영향을 받는다.
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 788         1       3    male  1.00      1      2   20.5750        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# ...

# %%
df.sort_values(by=["fare", "age"]).head(10)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 822         0       1  male  38.0      0      0   0.0        S   First  man
# 806         0       1  male  39.0      0      0   0.0        S   First  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 413         0       2  male   NaN      0      0   0.0        S  Second  man
# 466         0       2  male   NaN      0      0   0.0        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 302        True  NaN  Southampton    no   True
# ...

# %%
df.sort_values(by=["pclass","fare"]).head(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 263         0       1    male  40.0      0      0   0.0000        S  First
# 633         0       1    male   NaN      0      0   0.0000        S  First
# 806         0       1    male  39.0      0      0   0.0000        S  First
# 815         0       1    male   NaN      0      0   0.0000        S  First
# 822         0       1    male  38.0      0      0   0.0000        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 662         0       1    male  47.0      0      0  25.5875        S  First
# 168         0       1    male   NaN      0      0  25.9250        S  First
# 796         1       1  female  49.0      0      0  25.9292        S  First
# 862         1       1  female  48.0      0      0  25.9292        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 263    man        True    B  Southampton    no   True
# ...

# %%
df.sort_values(by=["fare", "pclass"]).head(10)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 633         0       1  male   NaN      0      0   0.0        S   First  man
# 806         0       1  male  39.0      0      0   0.0        S   First  man
# 815         0       1  male   NaN      0      0   0.0        S   First  man
# 822         0       1  male  38.0      0      0   0.0        S   First  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 413         0       2  male   NaN      0      0   0.0        S  Second  man
# 466         0       2  male   NaN      0      0   0.0        S  Second  man
# 481         0       2  male   NaN      0      0   0.0        S  Second  man
# 674         0       2  male   NaN      0      0   0.0        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 263        True    B  Southampton    no   True
# ...

# %% [markdown]
# # 연습문제

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.sort_values(by=["total_bill", "tip"], ascending=False).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4

# %%
tips.sort_values(by=["size", "tip"], ascending=[False, True]).head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 153       24.55  2.00    Male     No   Sun  Dinner     4

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[5, "class"]
# Out:
# 'Third'

# %%
df.loc[2:4, ["pclass", "class"]] # fancy indexing
# Out:
#    pclass  class
# 2       3  Third
# 3       1  First
# 4       3  Third

# %%
df.loc[2:4, "fare":"class"]
# Out:
#      fare embarked  class
# 2   7.925        S  Third
# 3  53.100        S  First
# 4   8.050        S  Third

# %%
condition=(df["who"]=="man")
condition
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: who, Length: 891, dtype: bool

# %%
df.loc[condition].head() # loc을 이용해주는 것이 좋다.
# 이런 방식을 이용해서 원하는 자리에 원하는 값을 대입해줄 수 있다.
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  22.0      1      0   7.2500        S  Third  man
# 4          0       3  male  35.0      0      0   8.0500        S  Third  man
# 5          0       3  male   NaN      0      0   8.4583        Q  Third  man
# 6          0       1  male  54.0      0      0  51.8625        S  First  man
# 12         0       3  male  20.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %%
condition1=df["fare"]>30
condition2=df["sex"]=="female"
condition=condition1&condition2
condition
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.loc[condition]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 25          1       3  female  38.0      1      5   31.3875        S   Third
# 31          1       1  female   NaN      1      0  146.5208        C   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 853         1       1  female  16.0      0      1   39.4000        S   First
# 856         1       1  female  45.0      1      1  164.8667        S   First
# 863         0       3  female   NaN      8      2   69.5500        S   Third
# 871         1       1  female  47.0      1      1   52.5542        S   First
# 879         1       1  female  56.0      0      1   83.1583        C   First
#
# ...

# %%
condition=condition1|condition2
df.loc[condition]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 연습문제

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
condition_man=((df["sex"]=="male")&(df["who"]=="man"))
condition_age=df["age"]>=30
condition=condition_man&condition_age
condition
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Length: 891, dtype: bool

# %%
df=df.loc[condition]
df
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 13          0       3  male  39.0      1      5  31.2750        S   Third
# 20          0       2  male  35.0      0      0  26.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 867         0       1  male  31.0      0      0  50.4958        S   First
# 872         0       1  male  33.0      0      0   5.0000        S   First
# 873         0       3  male  47.0      0      0   9.0000        S   Third
# 881         0       3  male  33.0      0      0   7.8958        S   Third
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sort_values(by="fare", ascending=False).head(10)
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked  class  \
# 679         1       1  male  36.0      0      1  512.3292        C  First
# 737         1       1  male  35.0      0      0  512.3292        C  First
# 438         0       1  male  64.0      1      4  263.0000        S  First
# 332         0       1  male  38.0      0      1  153.4625        S  First
# 660         1       1  male  50.0      2      0  133.6500        S  First
# 390         1       1  male  36.0      1      2  120.0000        S  First
# 659         0       1  male  58.0      0      2  113.2750        C  First
# 698         0       1  male  49.0      1      1  110.8833        C  First
# 544         0       1  male  50.0      1      0  106.4250        C  First
# 224         1       1  male  38.0      1      0   90.0000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 679  man        True    B    Cherbourg   yes  False
# ...

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
condition_age=(df["age"]>=20)&(df["age"]<40)
condition_pclass=(df["pclass"]==1)|(df["pclass"]==2)
condition=condition_age&condition_pclass
condition
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890    False
# Length: 891, dtype: bool

# %%
columns_name=["survived", "pclass", "age", "fare"]
df.loc[condition, columns_name].head(10)
# Out:
#     survived  pclass   age     fare
# 1          1       1  38.0  71.2833
# 3          1       1  35.0  53.1000
# 20         0       2  35.0  26.0000
# 21         1       2  34.0  13.0000
# 23         1       1  28.0  35.5000
# 34         0       1  28.0  82.1708
# 41         0       2  27.0  21.0000
# 53         1       2  29.0  26.0000
# 56         1       2  21.0  10.5000
# 61         1       1  38.0  80.0000

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
condition=(df["pclass"]==1)|(df["pclass"]==2)
condition
age_mean=df["age"].mean()
age_mean
# Out:
# 29.69911764705882

# %%
df.loc[condition, "age"]=df.loc[condition, "age"].fillna(age_mean) # fillna를 이용해서 원하는 값을 원하는 자리에 넣어주기.
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(df['age'].isnull().sum())
print(df['age'].mean())
# Out:
# 136
# 29.69911764705882

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.iloc[1,3]
# Out:
# 38.0

# %%
df.iloc[[0,1,2], [3,5,7]]
# Out:
#     age  parch embarked
# 0  22.0      0        S
# 1  38.0      0        C
# 2  26.0      0        S

# %%
df.iloc[0:2, 3:7]
# Out:
#     age  sibsp  parch     fare
# 0  22.0      1      0   7.2500
# 1  38.0      1      0  71.2833

# %%
df["fare"].where(df["fare"]<30, 0).tail()
# Out:
# 886    13.00
# 887     0.00
# 888    23.45
# 889     0.00
# 890     7.75
# Name: fare, dtype: float64

# %%
df["sex"].where(df["sex"]=="female", "not-female").tail()
# Out:
# 886    not-female
# 887        female
# 888        female
# 889    not-female
# 890    not-female
# Name: sex, dtype: object

# %%
df["sex"].mask(df["sex"]=="female", "FEMALE").tail()
# Out:
# 886      male
# 887    FEMALE
# 888    FEMALE
# 889      male
# 890      male
# Name: sex, dtype: object

# %%
df["pclass"].where(df["pclass"]==1, "not-1").tail(10) # (1등급인 경우, 1등급이 아닌 경우)
# Out:
# 881    not-1
# 882    not-1
# 883    not-1
# 884    not-1
# 885    not-1
# 886    not-1
# 887        1
# 888    not-1
# 889        1
# 890    not-1
# Name: pclass, dtype: object

# %%
df["pclass"].mask(df["pclass"]==1, "Super-class").tail(10) # (1등급인 경우, 1등급인 경우 넣어주는 데이터)
# Out:
# 881              3
# 882              3
# 883              2
# 884              3
# 885              3
# 886              2
# 887    Super-class
# 888              3
# 889    Super-class
# 890              3
# Name: pclass, dtype: object

# %%
sample = pd.DataFrame({'name': ['kim', 'lee', 'park', 'choi'], 
                        'age': [24, 27, 34, 19]
                      })
sample
# Out:
#    name  age
# 0   kim   24
# 1   lee   27
# 2  park   34
# 3  choi   19

# %%
sample["name"].isin(["kim", "lee"])
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: name, dtype: bool

# %%
condition=sample["name"].isin(["kim", "lee"]) # 조건
sample.loc[condition]
# Out:
#   name  age
# 0  kim   24
# 1  lee   27

# %%
sample.loc[condition, "age"]
# Out:
# 0    24
# 1    27
# Name: age, dtype: int64

# %% [markdown]
# # 연습문제

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
condition_day=tips["day"].isin(["Fri","Sat"])
condition_tip=tips["tip"]<10
condition=condition_day&condition_tip
condition
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Length: 244, dtype: bool

# %%
tips_columns=["total_bill", "tip", "smoker", "time"]
tips.loc[condition, tips_columns].head(10)
# Out:
#     total_bill   tip smoker    time
# 19       20.65  3.35     No  Dinner
# 20       17.92  4.08     No  Dinner
# 21       20.29  2.75     No  Dinner
# 22       15.77  2.23     No  Dinner
# 23       39.42  7.58     No  Dinner
# 24       19.82  3.18     No  Dinner
# 25       17.81  2.34     No  Dinner
# 26       13.37  2.00     No  Dinner
# 27       12.69  2.00     No  Dinner
# 28       21.70  4.30     No  Dinner
